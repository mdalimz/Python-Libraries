# %%
import pandas as pd

# %%
diamond=pd.read_csv('D:/New folder/diamonds.csv')
diamond
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
diamond.tail(100)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53840       53841   0.71       Good     H    VVS2   60.4   63.0   2738  5.69
# 53841       53842   0.80  Very Good     H     SI1   63.8   56.0   2739  5.85
# 53842       53843   0.71      Ideal     H    VVS1   62.0   57.0   2739  5.71
# 53843       53844   0.57      Ideal     E    VVS1   61.8   56.0   2739  5.33
# 53844       53845   0.74  Very Good     D     SI2   61.5   59.0   2740  5.79
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53840  5.74  3.45
# ...

# %% [markdown]
# ## Scatter plot

# %%
# Scatter Plot: Age vs Salary
diamond.plot.scatter(y='carat', x='price', title='Scatter Plot: Carat vs Price (53940 rows × 11 columns) ', 
                              xlabel='Price', ylabel='Carat', grid= True)
# Out:
# <AxesSubplot:title={'center':'Scatter Plot: Carat vs Price (53940 rows × 11 columns) '}, xlabel='Price', ylabel='Carat'>

# %% [markdown]
# # Line Plot

# %%
diamond.head(500).plot.line(y='carat', x='depth', title='Scatter Plot: carat vs price (500 rows × 11 columns) ', 
                              xlabel='Carat', ylabel='Depth', color='r', marker='o', linestyle='-',grid= True)
# Out:
# <AxesSubplot:title={'center':'Scatter Plot: carat vs price (500 rows × 11 columns) '}, xlabel='Carat', ylabel='Depth'>

# %% [markdown]
# ## Histogram

# %%
diamond['carat'].plot.hist(title='carat distribution, 53940 rows × 11 columns',color="yellow")
# Out:
# <AxesSubplot:title={'center':'carat distribution, 53940 rows × 11 columns'}, ylabel='Frequency'>

# %% [markdown]
# ## Boxplot

# %%
diamond.boxplot(column='price', by='color', grid=True, vert=False)  # no title
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='color'>

# %% [markdown]
# ## Bar Plot

# %%
diamond['clarity'].value_counts().plot.bar(title='Diamond count by clarity ')
# Out:
# <AxesSubplot:title={'center':'Diamond count by clarity '}>

# %% [markdown]
# ## Area Plot

# %%
diamond.plot.area(y='price', x='color', title='',
                       xlabel='color', ylabel='price', color='g', legend=True, grid=True)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %% [markdown]
# ## Pie chart

# %%
# Pie Chart: Department-wise Salary distribution
diamond.groupby('color')['price'].sum().plot.pie(title='color-wise price Distribution', autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'color-wise price Distribution'}, ylabel='price'>
